# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import os
import matplotlib.pyplot as plt
from PIL import Image

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lasse\\Desktop\\DTU\\6. semester\\Social informatik\\Exam project local\\GitHub\\SocInfo2022'

# %%
text = open("text.txt").read()

wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
dove_mask = np.array(Image.open(r"C:\Users\Lasse\Desktop\DTU\6. semester\Social informatik\Exam project local\GitHub\SocInfo2022\Illustrations\Biden_silhouette_background.png"))
#dove_mask[230:250, 240:250]
plt.imshow(dove_mask)
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(background_color="white", 
                      mask=dove_mask,
                      contour_width=3, 
                      repeat=True,
                      width = 800,
                      height = 1600,
                      min_font_size=3,
                      contour_color='darkgreen')

# Generate a wordcloud
wordcloud.generate(text)

# store to file
wordcloud.to_file("Biden_cloud.png")

# show
plt.figure( figsize=(8,16) )
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
#plt.savefig("Trump_cloud.png")
